# %%
import pandas as pd

# %%
metadata_df = pd.read_csv("../data/metadata/metadata_book.csv")

# %%
metadata_df.head()
# Out:
#          id                 name  text_path  audio_path  \
# 0  9600eefb  chut-phan-linh-đinh        NaN         NaN
# 1  35116471              ivanhoe        NaN         NaN
# 2  17ae223a      ai-vao-đia-nguc        NaN         NaN
# 3  71bfbba6              unknown        NaN         NaN
# 4  3ce51220              unknown        NaN         NaN
#
#                                             narrator  duration  \
# 0  [{'id': '96ec76e2', 'name': 'Quốc Thịnh', 'dia...    4.5728
# 1  {'id': '4fa20657', 'name': 'Ngô Hồng', 'dialec...   20.0233
# 2  {'id': '78a1a748', 'name': 'Thanh Cúc', 'diale...    3.1058
# 3  {'id': '8068a8b5', 'name': 'Tịnh Khẩu', 'diale...    5.2392
# 4  {'id': '60b7bfba', 'name': 'Thủy Tiên', 'diale...    4.6847
#
#              author                                           text_url  \
# 0     Hồ Biểu Chánh  ['https://thuviensachpdf.com/chut-phan-linh-di...
# 1  Sir Walter Scott  ['https://thuviensachpdf.com/ivanhoe', 'thuvie...
# ...

# %%
metadata_df["text_download_url"].isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4        True
#         ...
# 3381     True
# 3382     True
# 3383     True
# 3384     True
# 3385     True
# Name: text_download_url, Length: 3386, dtype: bool

# %%
able_download_df = metadata_df[~metadata_df["text_download_url"].isna()]

# %%
able_download_df.head()
# Out:
#           id                 name  text_path  audio_path  \
# 0   9600eefb  chut-phan-linh-đinh        NaN         NaN
# 1   35116471              ivanhoe        NaN         NaN
# 2   17ae223a      ai-vao-đia-nguc        NaN         NaN
# 10  301cc24d       loan-mat-nhung        NaN         NaN
# 11  9e4ded5a    con-mua-đinh-menh        NaN         NaN
#
#                                              narrator  duration  \
# 0   [{'id': '96ec76e2', 'name': 'Quốc Thịnh', 'dia...    4.5728
# 1   {'id': '4fa20657', 'name': 'Ngô Hồng', 'dialec...   20.0233
# 2   {'id': '78a1a748', 'name': 'Thanh Cúc', 'diale...    3.1058
# 10  {'id': '6d888de2', 'name': 'Hồng Nhung', 'dial...   18.0425
# 11  {'id': '8ee20572', 'name': 'Thanh Mai', 'diale...   15.1964
#
#               author                                           text_url  \
# 0      Hồ Biểu Chánh  ['https://thuviensachpdf.com/chut-phan-linh-di...
# 1   Sir Walter Scott  ['https://thuviensachpdf.com/ivanhoe', 'thuvie...
# ...

# %%
unknown_name_df = able_download_df[able_download_df["name"] == "unknown"]
unknown_name_df.head()
# Out:
#             id     name  text_path  audio_path  \
# 540   b02af099  unknown        NaN         NaN
# 657   012d7cd3  unknown        NaN         NaN
# 1711  fc6cd4d0  unknown        NaN         NaN
# 1806  e9568ef8  unknown        NaN         NaN
# 2639  02433e94  unknown        NaN         NaN
#
#                                                narrator  duration   author  \
# 540   {'id': '0047d286', 'name': 'Hồng Nhung', 'dial...   36.0336  Unknown
# 657   {'id': 'b26ce358', 'name': 'Bi', 'dialect': No...   27.3447  Unknown
# 1711  {'id': 'd0c4becc', 'name': 'Cara', 'dialect': ...   14.0558  Unknown
# 1806  {'id': '0c0d06dc', 'name': 'Hamlet Trương', 'd...    1.5517  Unknown
# 2639  {'id': 'ecfb0c16', 'name': 'Xuân Mai', 'dialec...    2.5525  Unknown
#
#                                                text_url  \
# 540   ['https://thuviensachpdf.com/ban-chat-cua-di',...
# 657   ['https://thuviensachpdf.com/dao-tinh', 'thuvi...
# ...

# %%
def get_name_from_url(url):
  return url.split("/")[-1].split(".")[0]


unknown_name_df["name"] = unknown_name_df["audio_url"].apply(get_name_from_url)
unknown_name_df
# Out:
# /tmp/ipykernel_43173/1297828518.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unknown_name_df["name"] = unknown_name_df["audio_url"].apply(get_name_from_url)
#             id                      name  text_path  audio_path  \
# 540   b02af099           ban-chat-cua-di        NaN         NaN
# 657   012d7cd3                  dao-tinh        NaN         NaN
# 1711  fc6cd4d0  huong-mat-tua-khoi-suong        NaN         NaN
# 1806  e9568ef8          ai-roi-cung-khac        NaN         NaN
# 2639  02433e94         ba-oi-minh-di-dau        NaN         NaN
# 2759  5c5ca8ae        tro-lai-hoang-thon        NaN         NaN
#
#                                                narrator  duration   author  \
# ...

# %%
def get_name_from_url(url):
  return url.split("/")[-1].split(".")[0]


able_download_df.loc[:, "name"] = able_download_df["audio_url"].apply(get_name_from_url)

# %%
able_download_df.to_csv("../data/metadata/able_download_metadata.csv", index=False)

# %%
able_download_df[able_download_df["duration"].isna()]
# Out:
#            id                 name  text_path  audio_path  \
# 535  62f9d333  con-duong-may-trang        NaN         NaN
#
#                                               narrator  duration author  \
# 535  {'id': 'c059b03d', 'name': 'Giang Nguyễn', 'di...       NaN   Osho
#
#                                               text_url  \
# 535  ['https://thuviensachpdf.com/con-duong-may-tra...
#
#                                              audio_url  alignment_path  \
# 535  https://sachnoiviet.net/sach-noi/con-duong-may...             NaN
#
#                                      text_download_url  \
# 535  https://cloud.thuviensachpdf.com/pdf/vi/con-du...
#
#                                     audio_download_url  sample_rate  quality  \
# 535  ['https://archive.org/download/con-duong-2_202...          NaN      NaN
#
#      word_count  num_sentences  audio_size  text_size
# 535         NaN            NaN         NaN        NaN

# %%
able_download_df.to_json(
  "../data/metadata/able_download_metadata.json",
  orient="records",
  force_ascii=True,
  indent=2,
)

# %%
final_df = able_download_df[able_download_df["duration"] <= 10]

# %%
final_df["duration"].describe()
# Out:
# count    777.000000
# mean       5.119023
# std        2.233368
# min        0.379200
# 25%        3.322200
# 50%        5.004700
# 75%        6.750600
# max        9.949200
# Name: duration, dtype: float64

# %%
final_df["duration"].sum()
# Out:
# np.float64(3977.4805)

# %%
final_df.to_csv("../data/metadata/able_download_less_10_hour_metadata.csv", index=False)

# %%
final_df.reset_index(inplace=True, drop=True)

# %%
final_df.iloc[final_df["duration"].idxmax()]
# Out:
# id                                                             5376c7fa
# name                                                 con-da-co-duong-di
# text_path                                                           NaN
# audio_path                                                          NaN
# narrator              {'id': 'f9c7f063', 'name': 'Hướng Dương', 'dia...
# duration                                                         9.9492
# author                                                  Thích Nhất Hạnh
# text_url              ['https://thuviensachpdf.com/con-da-co-duong-d...
# audio_url             https://sachnoiviet.net/sach-noi/con-da-co-duo...
# alignment_path                                                      NaN
# text_download_url     https://cloud.thuviensachpdf.com/pdf/vi/con-da...
# audio_download_url    ['https://archive.org/download/con-da-11/con-d...
# sample_rate                                                         NaN
# ...
